# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# Importing the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading the dataset
admission = pd.read_csv("Admission_Prediction.csv")

# Viewing first 5 rows of the dataset
admission.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1      337.0        118.0                4.0  4.5  4.5  9.65
# 1           2      324.0        107.0                4.0  4.0  4.5  8.87
# 2           3        NaN        104.0                3.0  3.0  3.5  8.00
# 3           4      322.0        110.0                3.0  3.5  2.5  8.67
# 4           5      314.0        103.0                2.0  2.0  3.0  8.21
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.76
# 2         1             0.72
# 3         1             0.80
# 4         0             0.65

# %%
# Basic Info about dataset
admission.info()

# Statistical Summary of dataset
admission.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          485 non-null    float64
#  2   TOEFL Score        490 non-null    float64
#  3   University Rating  485 non-null    float64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(7), int64(2)
# memory usage: 35.3 KB
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  500.000000  485.000000   490.000000         485.000000  500.000000
# mean   250.500000  316.558763   107.187755           3.121649    3.374000
# ...

# %%
# Checking the data distribution in "GRE Score" Column
sns.distplot(admission["GRE Score"])
#---Normally Distributed---Gaussian Distribution

# %%
# Checking the data distribution in "TOEFL Score" Column
sns.distplot(admission["TOEFL Score"])
#---Normally Distributed---Gaussian Distribution

# %%
# Checking the data distribution in "University Rating" Column
sns.distplot(admission["University Rating"])
#---Normally Distributed---Gaussian Distribution

# %%
# Checking the data distribution in "SOP" Column
sns.distplot(admission["SOP"])
#---Normally Distributed---Gaussian Distribution

# %%
# Checking the data distribution in "LOR" Column
sns.distplot(admission["LOR"])
#---Normally Distributed---Gaussian Distribution

# %%
# Checking the data distribution in "CGPA" Column
sns.distplot(admission["CGPA"])
#---Normally Distributed---Gaussian Distribution

# %%
# Checking the data distribution in "Research" Column
sns.distplot(admission["Research"])
#---Normally Distributed---Gaussian Distribution

# %%
# Finding the frequency of occurance of each values
admission["Research"].value_counts()

# Finding the percentage of the frequency of each values
admission["Research"].value_counts(normalize = True)

# Visualising the frequency
sns.countplot(x = "Research", data = admission)
# Out:
# 1    280
# 0    220
# Name: Research, dtype: int64
# 1    0.56
# 0    0.44
# Name: Research, dtype: float64

# %%
# Checking the data distribution in "Chance of Admit" (Target) Column
sns.distplot(admission["Chance of Admit"])
#---Normally Distributed---Gaussian Distribution

# %%
# Visualizing relationship between "GRE Score" and target variable
sns.scatterplot(x = "GRE Score", y = "Chance of Admit", data = admission)
#---Depicting Linear relationship

# %%
# Visualizing relationship between "TOEFL Score" and target variable
sns.scatterplot(x = "TOEFL Score", y = "Chance of Admit", data = admission)
#---Depicting Linear relationship

# %%
# Visualizing relationship between "University Rating" and target variable
sns.scatterplot(x = "University Rating", y = "Chance of Admit", data = admission)
#---Depicting Linear relationship

# %%
# Visualizing relationship between "SOP" and target variable
sns.scatterplot(x = "SOP", y = "Chance of Admit", data = admission)
#---Depicting Linear relationship

# %%
# Visualizing relationship between "LOR" and target variable
sns.scatterplot(x = "LOR", y = "Chance of Admit", data = admission)
#---Depicting Linear relationship

# %%
# Visualizing relationship between "CGPA" and target variable
sns.scatterplot(x = "CGPA", y = "Chance of Admit", data = admission)
#---Depicting Linear relationship

# %%
# Visualizing relationship between "Research" and target variable
sns.scatterplot(x = "Research", y = "Chance of Admit", data = admission)
#---Depicting Linear relationship
